# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
import os
import sys
from pydub import AudioSegment

# %%
folder="./Tamil-English/AUDIO/"
audio_clips=os.listdir(folder)
print("No. of .wav files in audio folder = ",len(audio_clips))
# Out:
# No. of .wav files in audio folder =  390

# %%
for filename in os.listdir(folder):
       infilename = os.path.join(folder,filename)
       if not os.path.isfile(infilename): continue
       oldbase = os.path.splitext(filename)
       newname = infilename.replace('.tmp', '.m4a')
       output = os.rename(infilename, newname)

# %%
formats_to_convert = ['.m4a','.ogg']

for (dirpath, dirnames, filenames) in os.walk(folder):
    for filename in filenames:
        if filename.endswith(tuple(formats_to_convert)):

            filepath = dirpath + '/' + filename
            (path, file_extension) = os.path.splitext(filepath)
            file_extension_final = file_extension.replace('.', '')
            try:
                track = AudioSegment.from_file(filepath,
                        file_extension_final)
                wav_filename = filename.replace(file_extension_final, 'wav')
                wav_path = dirpath + '/' + wav_filename
                print('CONVERTING: ' + str(filepath))
                file_handle = track.export(wav_path, format='wav')
                os.remove(filepath)
            except:
                print("ERROR CONVERTING " + str(filepath))
# Out:
# CONVERTING: ./Tamil-English/AUDIO//D1.ogg
# CONVERTING: ./Tamil-English/AUDIO//D10.ogg
# CONVERTING: ./Tamil-English/AUDIO//D11.ogg
# CONVERTING: ./Tamil-English/AUDIO//D12.ogg
# CONVERTING: ./Tamil-English/AUDIO//D13.ogg
# CONVERTING: ./Tamil-English/AUDIO//D14.ogg
# CONVERTING: ./Tamil-English/AUDIO//D15.ogg
# CONVERTING: ./Tamil-English/AUDIO//D2.ogg
# CONVERTING: ./Tamil-English/AUDIO//D3.ogg
# CONVERTING: ./Tamil-English/AUDIO//D4.ogg
# CONVERTING: ./Tamil-English/AUDIO//D5.ogg
# CONVERTING: ./Tamil-English/AUDIO//D51.ogg
# CONVERTING: ./Tamil-English/AUDIO//D52.ogg
# CONVERTING: ./Tamil-English/AUDIO//D53.ogg
# CONVERTING: ./Tamil-English/AUDIO//D54.ogg
# CONVERTING: ./Tamil-English/AUDIO//D55.ogg
# CONVERTING: ./Tamil-English/AUDIO//D56.ogg
# CONVERTING: ./Tamil-English/AUDIO//D57.ogg
# CONVERTING: ./Tamil-English/AUDIO//D58.ogg
# CONVERTING: ./Tamil-English/AUDIO//D59.ogg
# CONVERTING: ./Tamil-English/AUDIO//D6.ogg
# CONVERTING: ./Tamil-English/AUDIO//D60.ogg
# CONVERTING: ./Tamil-English/AUDIO//D61.ogg
# CONVERTING: ./Tamil-English/AUDIO//D7.ogg
# CONVERTING: ./Tamil-English/AUDIO//D8.ogg
# CONVERTING: ./Tamil-English/AUDIO//D9.ogg
# CONVERTING: ./Tamil-English/AUDIO//T1.ogg
# CONVERTING: ./Tamil-English/AUDIO//T10.ogg
# CONVERTING: ./Tamil-English/AUDIO//T100.ogg
# CONVERTING: ./Tamil-English/AUDIO//T101.ogg
# CONVERTING: ./Tamil-English/AUDIO//T102.ogg
# CONVERTING: ./Tamil-English/AUDIO//T103.ogg
# CONVERTING: ./Tamil-English/AUDIO//T104.ogg
# CONVERTING: ./Tamil-English/AUDIO//T105.ogg
# CONVERTING: ./Tamil-English/AUDIO//T106.ogg
# CONVERTING: ./Tamil-English/AUDIO//T107.ogg
# CONVERTING: ./Tamil-English/AUDIO//T108.ogg
# CONVERTING: ./Tamil-English/AUDIO//T109.ogg
# CONVERTING: ./Tamil-English/AUDIO//T11.ogg
# CONVERTING: ./Tamil-English/AUDIO//T110.ogg
# CONVERTING: ./Tamil-English/AUDIO//T111.ogg
# CONVERTING: ./Tamil-English/AUDIO//T112.ogg
# CONVERTING: ./Tamil-English/AUDIO//T113.ogg
# CONVERTING: ./Tamil-English/AUDIO//T114.ogg
# CONVERTING: ./Tamil-English/AUDIO//T115.ogg
# CONVERTING: ./Tamil-English/AUDIO//T116.ogg
# CONVERTING: ./Tamil-English/AUDIO//T117.ogg
# CONVERTING: ./Tamil-English/AUDIO//T118.ogg
# CONVERTING: ./Tamil-English/AUDIO//T119.ogg
# CONVERTING: ./Tamil-English/AUDIO//T12.ogg
# CONVERTING: ./Tamil-English/AUDIO//T120.ogg
# CONVERTING: ./Tamil-English/AUDIO//T121.ogg
# CONVERTING: ./Tamil-English/AUDIO//T122.ogg
# CONVERTING: ./Tamil-English/AUDIO//T123.ogg
# CONVERTING: ./Tamil-English/AUDIO//T124.ogg
# CONVERTING: ./Tamil-English/AUDIO//T125.ogg
# CONVERTING: ./Tamil-English/AUDIO//T126.ogg
# CONVERTING: ./Tamil-English/AUDIO//T127.ogg
# CONVERTING: ./Tamil-English/AUDIO//T128.ogg
# CONVERTING: ./Tamil-English/AUDIO//T129.ogg
# CONVERTING: ./Tamil-English/AUDIO//T13.ogg
# CONVERTING: ./Tamil-English/AUDIO//T130.ogg
# CONVERTING: ./Tamil-English/AUDIO//T131.ogg
# CONVERTING: ./Tamil-English/AUDIO//T132.ogg
# CONVERTING: ./Tamil-English/AUDIO//T133.ogg
# CONVERTING: ./Tamil-English/AUDIO//T134.ogg
# CONVERTING: ./Tamil-English/AUDIO//T135.ogg
# CONVERTING: ./Tamil-English/AUDIO//T136.ogg
# CONVERTING: ./Tamil-English/AUDIO//T137.ogg
# CONVERTING: ./Tamil-English/AUDIO//T138.ogg
# CONVERTING: ./Tamil-English/AUDIO//T139.ogg
# CONVERTING: ./Tamil-English/AUDIO//T14.ogg
# CONVERTING: ./Tamil-English/AUDIO//T140.ogg
# CONVERTING: ./Tamil-English/AUDIO//T141.ogg
# CONVERTING: ./Tamil-English/AUDIO//T142.ogg
# CONVERTING: ./Tamil-English/AUDIO//T143.ogg
# CONVERTING: ./Tamil-English/AUDIO//T144.ogg
# CONVERTING: ./Tamil-English/AUDIO//T145.ogg
# CONVERTING: ./Tamil-English/AUDIO//T146.ogg
# CONVERTING: ./Tamil-English/AUDIO//T147.ogg
# CONVERTING: ./Tamil-English/AUDIO//T148.ogg
# CONVERTING: ./Tamil-English/AUDIO//T149.ogg
# CONVERTING: ./Tamil-English/AUDIO//T15.ogg
# CONVERTING: ./Tamil-English/AUDIO//T150.ogg
# CONVERTING: ./Tamil-English/AUDIO//T151.ogg
# CONVERTING: ./Tamil-English/AUDIO//T152.ogg
# CONVERTING: ./Tamil-English/AUDIO//T153.ogg
# CONVERTING: ./Tamil-English/AUDIO//T154.ogg
# CONVERTING: ./Tamil-English/AUDIO//T155.ogg
# CONVERTING: ./Tamil-English/AUDIO//T156.ogg
# CONVERTING: ./Tamil-English/AUDIO//T157.ogg
# CONVERTING: ./Tamil-English/AUDIO//T158.ogg
# CONVERTING: ./Tamil-English/AUDIO//T159.ogg
# CONVERTING: ./Tamil-English/AUDIO//T16.ogg
# CONVERTING: ./Tamil-English/AUDIO//T160.ogg
# CONVERTING: ./Tamil-English/AUDIO//T161.ogg
# CONVERTING: ./Tamil-English/AUDIO//T162.ogg
# CONVERTING: ./Tamil-English/AUDIO//T163.ogg
# CONVERTING: ./Tamil-English/AUDIO//T164.ogg
# CONVERTING: ./Tamil-English/AUDIO//T165.ogg
# CONVERTING: ./Tamil-English/AUDIO//T166.ogg
# CONVERTING: ./Tamil-English/AUDIO//T167.ogg
# CONVERTING: ./Tamil-English/AUDIO//T168.ogg
# CONVERTING: ./Tamil-English/AUDIO//T169.ogg
# CONVERTING: ./Tamil-English/AUDIO//T17.ogg
# CONVERTING: ./Tamil-English/AUDIO//T170.ogg
# CONVERTING: ./Tamil-English/AUDIO//T171.ogg
# CONVERTING: ./Tamil-English/AUDIO//T172.ogg
# CONVERTING: ./Tamil-English/AUDIO//T173.ogg
# CONVERTING: ./Tamil-English/AUDIO//T174.ogg
# CONVERTING: ./Tamil-English/AUDIO//T175.ogg
# CONVERTING: ./Tamil-English/AUDIO//T176.ogg
# CONVERTING: ./Tamil-English/AUDIO//T177.ogg
# CONVERTING: ./Tamil-English/AUDIO//T178.ogg
# CONVERTING: ./Tamil-English/AUDIO//T179.ogg
# CONVERTING: ./Tamil-English/AUDIO//T18.ogg
# CONVERTING: ./Tamil-English/AUDIO//T180.ogg
# CONVERTING: ./Tamil-English/AUDIO//T181.ogg
# CONVERTING: ./Tamil-English/AUDIO//T182.ogg
# CONVERTING: ./Tamil-English/AUDIO//T183.ogg
# CONVERTING: ./Tamil-English/AUDIO//T184.ogg
# CONVERTING: ./Tamil-English/AUDIO//T185.ogg
# CONVERTING: ./Tamil-English/AUDIO//T186.ogg
# CONVERTING: ./Tamil-English/AUDIO//T187.ogg
# CONVERTING: ./Tamil-English/AUDIO//T19.ogg
# CONVERTING: ./Tamil-English/AUDIO//T2.ogg
# CONVERTING: ./Tamil-English/AUDIO//T20.ogg
# CONVERTING: ./Tamil-English/AUDIO//T21.ogg
# CONVERTING: ./Tamil-English/AUDIO//T22.ogg
# CONVERTING: ./Tamil-English/AUDIO//T23.ogg
# CONVERTING: ./Tamil-English/AUDIO//T24.ogg
# CONVERTING: ./Tamil-English/AUDIO//T25.ogg
# CONVERTING: ./Tamil-English/AUDIO//T26.ogg
# CONVERTING: ./Tamil-English/AUDIO//T27.ogg
# CONVERTING: ./Tamil-English/AUDIO//T28.ogg
# CONVERTING: ./Tamil-English/AUDIO//T29.ogg
# CONVERTING: ./Tamil-English/AUDIO//T3.ogg
# CONVERTING: ./Tamil-English/AUDIO//T30.ogg
# CONVERTING: ./Tamil-English/AUDIO//T31.ogg
# CONVERTING: ./Tamil-English/AUDIO//T32.ogg
# CONVERTING: ./Tamil-English/AUDIO//T33.ogg
# CONVERTING: ./Tamil-English/AUDIO//T34.ogg
# CONVERTING: ./Tamil-English/AUDIO//T35.ogg
# CONVERTING: ./Tamil-English/AUDIO//T36.ogg
# CONVERTING: ./Tamil-English/AUDIO//T37.ogg
# CONVERTING: ./Tamil-English/AUDIO//T38.ogg
# CONVERTING: ./Tamil-English/AUDIO//T39.ogg
# CONVERTING: ./Tamil-English/AUDIO//T4.ogg
# CONVERTING: ./Tamil-English/AUDIO//T40.ogg
# CONVERTING: ./Tamil-English/AUDIO//T41.ogg
# CONVERTING: ./Tamil-English/AUDIO//T42.ogg
# CONVERTING: ./Tamil-English/AUDIO//T43.ogg
# CONVERTING: ./Tamil-English/AUDIO//T44.ogg
# CONVERTING: ./Tamil-English/AUDIO//T45.ogg
# CONVERTING: ./Tamil-English/AUDIO//T46.ogg
# CONVERTING: ./Tamil-English/AUDIO//T47.ogg
# CONVERTING: ./Tamil-English/AUDIO//T48.ogg
# CONVERTING: ./Tamil-English/AUDIO//T49.ogg
# CONVERTING: ./Tamil-English/AUDIO//T5.ogg
# CONVERTING: ./Tamil-English/AUDIO//T50.ogg
# CONVERTING: ./Tamil-English/AUDIO//T51.ogg
# CONVERTING: ./Tamil-English/AUDIO//T52.ogg
# CONVERTING: ./Tamil-English/AUDIO//T53.ogg
# CONVERTING: ./Tamil-English/AUDIO//T54.ogg
# CONVERTING: ./Tamil-English/AUDIO//T55.ogg
# CONVERTING: ./Tamil-English/AUDIO//T56.ogg
# CONVERTING: ./Tamil-English/AUDIO//T57.ogg
# CONVERTING: ./Tamil-English/AUDIO//T58.ogg
# CONVERTING: ./Tamil-English/AUDIO//T59.ogg
# CONVERTING: ./Tamil-English/AUDIO//T6.ogg
# CONVERTING: ./Tamil-English/AUDIO//T60.ogg
# CONVERTING: ./Tamil-English/AUDIO//T61.ogg
# CONVERTING: ./Tamil-English/AUDIO//T62.ogg
# CONVERTING: ./Tamil-English/AUDIO//T63.ogg
# CONVERTING: ./Tamil-English/AUDIO//T64.ogg
# CONVERTING: ./Tamil-English/AUDIO//T65.ogg
# CONVERTING: ./Tamil-English/AUDIO//T66.ogg
# CONVERTING: ./Tamil-English/AUDIO//T67.ogg
# CONVERTING: ./Tamil-English/AUDIO//T68.ogg
# CONVERTING: ./Tamil-English/AUDIO//T69.ogg
# CONVERTING: ./Tamil-English/AUDIO//T7.ogg
# CONVERTING: ./Tamil-English/AUDIO//T70.ogg
# CONVERTING: ./Tamil-English/AUDIO//T71.ogg
# CONVERTING: ./Tamil-English/AUDIO//T72.ogg
# CONVERTING: ./Tamil-English/AUDIO//T73.ogg
# CONVERTING: ./Tamil-English/AUDIO//T74.ogg
# CONVERTING: ./Tamil-English/AUDIO//T75.ogg
# CONVERTING: ./Tamil-English/AUDIO//T76.ogg
# CONVERTING: ./Tamil-English/AUDIO//T77.ogg
# CONVERTING: ./Tamil-English/AUDIO//T78.ogg
# CONVERTING: ./Tamil-English/AUDIO//T79.ogg
# CONVERTING: ./Tamil-English/AUDIO//T8.ogg
# CONVERTING: ./Tamil-English/AUDIO//T80.ogg
# CONVERTING: ./Tamil-English/AUDIO//T81.ogg
# CONVERTING: ./Tamil-English/AUDIO//T82.ogg
# CONVERTING: ./Tamil-English/AUDIO//T83.ogg
# CONVERTING: ./Tamil-English/AUDIO//T84.ogg
# CONVERTING: ./Tamil-English/AUDIO//T85.ogg
# CONVERTING: ./Tamil-English/AUDIO//T86.ogg
# CONVERTING: ./Tamil-English/AUDIO//T87.ogg
# CONVERTING: ./Tamil-English/AUDIO//T88.ogg
# CONVERTING: ./Tamil-English/AUDIO//T89.ogg
# CONVERTING: ./Tamil-English/AUDIO//T9.ogg
# CONVERTING: ./Tamil-English/AUDIO//T90.ogg
# CONVERTING: ./Tamil-English/AUDIO//T91.ogg
# CONVERTING: ./Tamil-English/AUDIO//T92.ogg
# CONVERTING: ./Tamil-English/AUDIO//T93.ogg
# CONVERTING: ./Tamil-English/AUDIO//T94.ogg
# CONVERTING: ./Tamil-English/AUDIO//T95.ogg
# CONVERTING: ./Tamil-English/AUDIO//T96.ogg
# CONVERTING: ./Tamil-English/AUDIO//T97.ogg
# CONVERTING: ./Tamil-English/AUDIO//T98.ogg
# CONVERTING: ./Tamil-English/AUDIO//T99.ogg
